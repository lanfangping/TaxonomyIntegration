# %%
import os
import json
import pandas as pd

# %%
# file_path = '../Yang2017_WikiSemanticIntention/edit_intention_dataset_processed.csv'
file_path = '../../Re3/data_human/revision/edits_s.csv'
# Step 1: Verify the file path
if not os.path.exists(file_path):
    print("File not found:", file_path)
else:
    print("File found:", file_path)

# df = pd.read_json(file_path)
df = pd.read_csv(file_path)

# Drop a column (e.g., 'column2')
# df = df.drop('Unnamed: 0', axis=1)
df.head()
# Out:
# File found: ../../Re3/data_human/revision/edits_s.csv
#    edit_index                   id doc_name    node_ix_src node_ix_tgt  \
# 0           0  10-ARR_v2_4@2===nan   10-ARR  10-ARR_v2_4@2         NaN
# 1           1  10-ARR_v2_5@1===nan   10-ARR  10-ARR_v2_5@1         NaN
# 2           2  10-ARR_v2_5@3===nan   10-ARR  10-ARR_v2_5@3         NaN
# 3           3  10-ARR_v2_5@4===nan   10-ARR  10-ARR_v2_5@4         NaN
# 4           4  10-ARR_v2_5@5===nan   10-ARR  10-ARR_v2_5@5         NaN
#
#                                             text_src text_tgt  \
# 0  With this in mind, it is natural to consider h...      NaN
# 1  Reflective listening asks the counselor not on...      NaN
# 2  However, people do not always say what they me...      NaN
# 3  Reflection, as the response made based on refl...      NaN
# 4  On the other hand, pressing the client to clar...      NaN
#
#                    a                  b                  c               gold  \
# 0          Add,Claim          Add,Claim          Add,Claim          Add,Claim
# 1          Add,Claim          Add,Claim          Add,Claim          Add,Claim
# 2          Add,Claim          Add,Claim          Add,Claim          Add,Claim
# 3          Add,Claim          Add,Claim          Add,Claim          Add,Claim
# 4  Add,Fact/Evidence  Add,Fact/Evidence  Add,Fact/Evidence  Add,Fact/Evidence
#
#   parent_node_src parent_node_tgt       sec_node_src sec_node_tgt sec_id_src  \
# 0   10-ARR_v2_4,p             NaN  10-ARR_v2_3,title          NaN          1
# 1   10-ARR_v2_5,p             NaN  10-ARR_v2_3,title          NaN          1
# 2   10-ARR_v2_5,p             NaN  10-ARR_v2_3,title          NaN          1
# 3   10-ARR_v2_5,p             NaN  10-ARR_v2_3,title          NaN          1
# 4   10-ARR_v2_5,p             NaN  10-ARR_v2_3,title          NaN          1
#
#   sec_id_tgt sec_title_src sec_title_tgt
# 0        NaN  Introduction           NaN
# 1        NaN  Introduction           NaN
# 2        NaN  Introduction           NaN
# 3        NaN  Introduction           NaN
# 4        NaN  Introduction           NaN

# %%
extracted_df = df[['text_src', 'text_tgt', 'gold']].copy()
extracted_df
# Out:
#                                                 text_src  \
# 0      With this in mind, it is natural to consider h...
# 1      Reflective listening asks the counselor not on...
# 2      However, people do not always say what they me...
# 3      Reflection, as the response made based on refl...
# 4      On the other hand, pressing the client to clar...
# ...                                                  ...
# 11643  We use the self-collected database that consis...
# 11644  The usage of the variables X i (k) is necessar...
# 11645  Our data was acquired over four years (Novembe...
# 11646  In the research by Clark et al. ( Clark, 2015 ...
# 11647                         Discussion and conclusions
#
#                                                 text_tgt               gold
# 0                                                    NaN          Add,Claim
# 1                                                    NaN          Add,Claim
# 2                                                    NaN          Add,Claim
# 3                                                    NaN          Add,Claim
# 4                                                    NaN  Add,Fact/Evidence
# ...                                                  ...                ...
# 11643  We use the database that consists of 858 and 1...     Modify,Clarity
# 11644  The usage of the variables X i (k) is necessar...     Modify,Grammar
# 11645  Our data was acquired over four years (Novembe...     Modify,Grammar
# 11646  In the research by Clark et al ( Clark, 2015 ;...     Modify,Grammar
# 11647                         Discussion and Conclusions     Modify,Grammar
#
# [11648 rows x 3 columns]

# %%
extracted_df['annotator_labels'] = df.apply(lambda row: [row['a'], row['b'], row['c']], axis=1)
extracted_df
# Out:
#                                                 text_src  \
# 0      With this in mind, it is natural to consider h...
# 1      Reflective listening asks the counselor not on...
# 2      However, people do not always say what they me...
# 3      Reflection, as the response made based on refl...
# 4      On the other hand, pressing the client to clar...
# ...                                                  ...
# 11643  We use the self-collected database that consis...
# 11644  The usage of the variables X i (k) is necessar...
# 11645  Our data was acquired over four years (Novembe...
# 11646  In the research by Clark et al. ( Clark, 2015 ...
# 11647                         Discussion and conclusions
#
#                                                 text_tgt               gold  \
# 0                                                    NaN          Add,Claim
# 1                                                    NaN          Add,Claim
# 2                                                    NaN          Add,Claim
# 3                                                    NaN          Add,Claim
# 4                                                    NaN  Add,Fact/Evidence
# ...                                                  ...                ...
# 11643  We use the database that consists of 858 and 1...     Modify,Clarity
# 11644  The usage of the variables X i (k) is necessar...     Modify,Grammar
# 11645  Our data was acquired over four years (Novembe...     Modify,Grammar
# 11646  In the research by Clark et al ( Clark, 2015 ;...     Modify,Grammar
# 11647                         Discussion and Conclusions     Modify,Grammar
#
#                                         annotator_labels
# 0                      [Add,Claim, Add,Claim, Add,Claim]
# 1                      [Add,Claim, Add,Claim, Add,Claim]
# 2                      [Add,Claim, Add,Claim, Add,Claim]
# 3                      [Add,Claim, Add,Claim, Add,Claim]
# 4      [Add,Fact/Evidence, Add,Fact/Evidence, Add,Fac...
# ...                                                  ...
# 11643  [Modify,Fact/Evidence, Modify,Clarity, Modify,...
# 11644   [Modify,Grammar, Modify,Grammar, Modify,Grammar]
# 11645   [Modify,Grammar, Modify,Grammar, Modify,Grammar]
# 11646   [Modify,Grammar, Modify,Grammar, Modify,Grammar]
# 11647   [Modify,Grammar, Modify,Grammar, Modify,Grammar]
#
# [11648 rows x 4 columns]

# %%
extracted_df.fillna('', inplace=True)
extracted_df
# Out:
#                                                 text_src  \
# 0      With this in mind, it is natural to consider h...
# 1      Reflective listening asks the counselor not on...
# 2      However, people do not always say what they me...
# 3      Reflection, as the response made based on refl...
# 4      On the other hand, pressing the client to clar...
# ...                                                  ...
# 11643  We use the self-collected database that consis...
# 11644  The usage of the variables X i (k) is necessar...
# 11645  Our data was acquired over four years (Novembe...
# 11646  In the research by Clark et al. ( Clark, 2015 ...
# 11647                         Discussion and conclusions
#
#                                                 text_tgt               gold  \
# 0                                                                 Add,Claim
# 1                                                                 Add,Claim
# 2                                                                 Add,Claim
# 3                                                                 Add,Claim
# 4                                                         Add,Fact/Evidence
# ...                                                  ...                ...
# 11643  We use the database that consists of 858 and 1...     Modify,Clarity
# 11644  The usage of the variables X i (k) is necessar...     Modify,Grammar
# 11645  Our data was acquired over four years (Novembe...     Modify,Grammar
# 11646  In the research by Clark et al ( Clark, 2015 ;...     Modify,Grammar
# 11647                         Discussion and Conclusions     Modify,Grammar
#
#                                         annotator_labels
# 0                      [Add,Claim, Add,Claim, Add,Claim]
# 1                      [Add,Claim, Add,Claim, Add,Claim]
# 2                      [Add,Claim, Add,Claim, Add,Claim]
# 3                      [Add,Claim, Add,Claim, Add,Claim]
# 4      [Add,Fact/Evidence, Add,Fact/Evidence, Add,Fac...
# ...                                                  ...
# 11643  [Modify,Fact/Evidence, Modify,Clarity, Modify,...
# 11644   [Modify,Grammar, Modify,Grammar, Modify,Grammar]
# 11645   [Modify,Grammar, Modify,Grammar, Modify,Grammar]
# 11646   [Modify,Grammar, Modify,Grammar, Modify,Grammar]
# 11647   [Modify,Grammar, Modify,Grammar, Modify,Grammar]
#
# [11648 rows x 4 columns]

# %%
row = extracted_df.iloc[20]
row
# Out:
# text_src            4 The resulting sentences with medical concept...
# text_tgt            4 The resulting sentences are then considered ...
# gold                                             Modify,Fact/Evidence
# annotator_labels    [Modify,Fact/Evidence, Modify,Fact/Evidence, M...
# Name: 20, dtype: object

# %%
print(row['text_src'])
print(row['text_tgt'])
# Out:
# 4 The resulting sentences with medical concepts are then considered as knowledge candidates during our next step.
# 4 The resulting sentences are then considered as knowledge candidates during our next step.

# %%
extracted_df[['action', 'intention']] = extracted_df['gold'].str.split(',', expand=True)
extracted_df
# Out:
#                                                 text_src  \
# 0      With this in mind, it is natural to consider h...
# 1      Reflective listening asks the counselor not on...
# 2      However, people do not always say what they me...
# 3      Reflection, as the response made based on refl...
# 4      On the other hand, pressing the client to clar...
# ...                                                  ...
# 11643  We use the self-collected database that consis...
# 11644  The usage of the variables X i (k) is necessar...
# 11645  Our data was acquired over four years (Novembe...
# 11646  In the research by Clark et al. ( Clark, 2015 ...
# 11647                         Discussion and conclusions
#
#                                                 text_tgt               gold  \
# 0                                                                 Add,Claim
# 1                                                                 Add,Claim
# 2                                                                 Add,Claim
# 3                                                                 Add,Claim
# 4                                                         Add,Fact/Evidence
# ...                                                  ...                ...
# 11643  We use the database that consists of 858 and 1...     Modify,Clarity
# 11644  The usage of the variables X i (k) is necessar...     Modify,Grammar
# 11645  Our data was acquired over four years (Novembe...     Modify,Grammar
# 11646  In the research by Clark et al ( Clark, 2015 ;...     Modify,Grammar
# 11647                         Discussion and Conclusions     Modify,Grammar
#
#                                         annotator_labels  action  \
# 0                      [Add,Claim, Add,Claim, Add,Claim]     Add
# 1                      [Add,Claim, Add,Claim, Add,Claim]     Add
# 2                      [Add,Claim, Add,Claim, Add,Claim]     Add
# 3                      [Add,Claim, Add,Claim, Add,Claim]     Add
# 4      [Add,Fact/Evidence, Add,Fact/Evidence, Add,Fac...     Add
# ...                                                  ...     ...
# 11643  [Modify,Fact/Evidence, Modify,Clarity, Modify,...  Modify
# 11644   [Modify,Grammar, Modify,Grammar, Modify,Grammar]  Modify
# 11645   [Modify,Grammar, Modify,Grammar, Modify,Grammar]  Modify
# 11646   [Modify,Grammar, Modify,Grammar, Modify,Grammar]  Modify
# 11647   [Modify,Grammar, Modify,Grammar, Modify,Grammar]  Modify
#
#            intention
# 0              Claim
# 1              Claim
# 2              Claim
# 3              Claim
# 4      Fact/Evidence
# ...              ...
# 11643        Clarity
# 11644        Grammar
# 11645        Grammar
# 11646        Grammar
# 11647        Grammar
#
# [11648 rows x 6 columns]

# %%
repo="Re3"
n_sampels_pilot_study=15
n_sampels_pilot_study_list=[5, 5, 5]
n_samples_comparing_group=200
random_seed=41
group_by=['intention']

# repo="Wiki_pure"
# n_sampels_pilot_study=15
# n_sampels_pilot_study_list=[5, 5, 5]
# n_samples_comparing_group=52
# random_seed=41
# group_by=['label']

# repo="Wiki_code"
# n_sampels_pilot_study=15 # 5 samples per category over 14 categories
# n_sampels_pilot_study_list=[5, 5, 5]
# n_samples_comparing_group=77
# random_seed=41
# group_by=['label']

# repo="NewsEdits"
# n_sampels_pilot_study=100
# n_sampels_pilot_study_list=[30, 35, 35]
# n_samples_comparing_group=1000
# random_seed=41
# group_by=None

# repo="arXivEdits"
# n_sampels_pilot_study=15
# n_sampels_pilot_study_list=[5, 5, 5]
# n_samples_comparing_group=165
# random_seed=41
# group_by=['label']

# %%
# Define the sampling function
def sample_data(group, n=1, random_state=42):
    return group.sample(n=min(len(group), n), random_state=random_state)

# Sample n rows per 'domain' and 'label' combination with a random seed
if group_by is not None:
    sampled_df = extracted_df.groupby(group_by).apply(sample_data, n=n_sampels_pilot_study, random_state=random_seed).reset_index(drop=True)
else:
    sampled_df = extracted_df.sample(n=n_sampels_pilot_study, random_state=random_seed)

# Display the sampled DataFrame
sampled_df
# Out:
#                                              text_src  \
# 0   Mutations of the recombination-activating gene...
# 1   There are also national league tables, such as...
# 2   This relationship between researcher and sover...
# 3   However, the findings on beneficial effects ar...
# 4   TIFF files however can rarely be properly used...
# ..                                                ...
# 70
# 71  We use max-pooling to aggregate attention for ...
# 72    Training Details for Few-Shot Language Learners
# 73                                      Experiment 4a
# 74
#
#                                              text_tgt          gold  \
# 0                                                         Add,Claim
# 1   There are also national league tables, such as...  Modify,Claim
# 2                                                         Add,Claim
# 3                                                         Add,Claim
# 4                                                         Add,Claim
# ..                                                ...           ...
# 70                              Experimental Settings  Delete,Other
# 71  We use max-pooling to aggregate attention for ...  Modify,Other
# 72                                                        Add,Other
# 73                                       Experiment 4  Modify,Other
# 74                                Problem Formulation  Delete,Other
#
#                               annotator_labels  action intention
# 0            [Add,Claim, Add,Claim, Add,Claim]     Add     Claim
# 1   [Modify,Claim, Modify,Claim, Modify,Claim]  Modify     Claim
# 2            [Add,Claim, Add,Claim, Add,Claim]     Add     Claim
# 3            [Add,Claim, Add,Claim, Add,Claim]     Add     Claim
# 4            [Add,Claim, Add,Claim, Add,Claim]     Add     Claim
# ..                                         ...     ...       ...
# 70  [Delete,Other, Delete,Other, Delete,Other]  Delete     Other
# 71  [Modify,Other, Modify,Other, Modify,Claim]  Modify     Other
# 72           [Add,Other, Add,Other, Add,Other]     Add     Other
# 73  [Modify,Other, Modify,Other, Modify,Other]  Modify     Other
# 74  [Delete,Other, Delete,Other, Delete,Other]  Delete     Other
#
# [75 rows x 6 columns]

# %%
# Get the indices of the sampled data
sampled_indices = sampled_df.index

# Drop the sampled data to get the remaining data
remaining_df = extracted_df.drop(sampled_indices)

remaining_df = remaining_df.reset_index(drop=True)

# %%
# Convert DataFrame to JSON Lines format and save to a file
sampled_df.to_json(f"./pilot_study_{repo.lower()}.json", orient='records', lines=True)

remaining_df.to_json(f"./remaining_{repo.lower()}.json", orient='records', lines=True)

# %%
for idx, n_samples in enumerate(n_sampels_pilot_study_list):
    # Sample n rows per 'domain' and 'label' combination with a random seed
    if group_by is not None:
        sampled_iter_df = sampled_df.groupby(group_by).apply(sample_data, n=n_samples, random_state=random_seed).reset_index(drop=True)
    else:
        sampled_iter_df = sampled_df.sample(n=n_samples, random_state=random_seed)

    sampled_iter_df.to_json(f"./pilot_study_{repo.lower()}_iter{idx+1}.json", orient='records', lines=True)

    # Get the indices of the sampled data
    sampled_iter_indices = sampled_iter_df.index

    # Drop the sampled data to get the remaining data
    sampled_df = sampled_df.drop(sampled_iter_indices)
    # Reset the index
    sampled_df = sampled_df.reset_index(drop=True)

# %%
## dataset for comparing group

# Sample n rows per 'domain' and 'label' combination with a random seed
if group_by is not None:
    comparing_df = remaining_df.groupby(group_by).apply(sample_data, n=n_samples_comparing_group, random_state=random_seed).reset_index(drop=True)
else:
    comparing_df = remaining_df.sample(n=n_samples_comparing_group, random_state=random_seed).reset_index(drop=True)

comparing_df.to_json(f"./comparing_group_{repo.lower()}.json", orient='records', lines=True)
